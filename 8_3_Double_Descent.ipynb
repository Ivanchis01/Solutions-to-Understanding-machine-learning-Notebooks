# %% [markdown]
# <a href="https://colab.research.google.com/github/Ivanchis01/Solutions-to-Understanding-machine-learning-Notebooks/blob/main/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent** *Solution*

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-tytx6ljt
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-tytx6ljt
#   Resolved https://github.com/greydanus/mnist1d to commit 350929d12f4c9a4b7355e0c96604e41b9239bdb4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (2.31.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (1.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (2024.6.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post9) (1.16.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post9-py3-none-any.whl size=14496 sha256=8a33200b4f3fdf3e5b73e2e56582ef4fd9415b7bce2bc8c936e2d4826cc9269e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8qpz1fp0/wheels/41/95/55/45fcf7d38cfa97e35682da6c5017d4513729131326ce935371
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post9

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  # loop over the dataset n_epoch times
  n_epoch = 1000

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;
errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Train the model
    errors_train, errors_test = fit_model(model, data)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.241648, train error 83.22,  test loss 2.228325, test error 83.47
# Epoch   100, train loss 1.849506, train error 69.95,  test loss 1.705994, test error 67.88
# Epoch   200, train loss 1.848114, train error 70.20,  test loss 1.709657, test error 68.00
# Epoch   300, train loss 1.846473, train error 70.07,  test loss 1.698631, test error 68.15
# Epoch   400, train loss 1.847906, train error 70.70,  test loss 1.700872, test error 68.47
# Epoch   500, train loss 1.847240, train error 70.35,  test loss 1.700649, test error 67.97
# Epoch   600, train loss 1.845523, train error 70.32,  test loss 1.700804, test error 68.05
# Epoch   700, train loss 1.846963, train error 70.35,  test loss 1.706644, test error 68.25
# Epoch   800, train loss 1.846059, train error 70.40,  test loss 1.697593, test error 68.62
# Epoch   900, train loss 1.845786, train error 70.22,  test loss 1.697073, test error 68.40
# Training model with   4 hidden variables
# Epoch     0, train loss 2.253221, train error 86.55,  test loss 2.237980, test error 85.03
# Epoch   100, train loss 1.803092, train error 68.15,  test loss 1.651590, test error 64.28
# Epoch   200, train loss 1.785513, train error 66.68,  test loss 1.638755, test error 64.57
# Epoch   300, train loss 1.778254, train error 66.50,  test loss 1.643829, test error 64.85
# Epoch   400, train loss 1.774553, train error 65.75,  test loss 1.642867, test error 64.40
# Epoch   500, train loss 1.773975, train error 66.43,  test loss 1.631921, test error 65.12
# Epoch   600, train loss 1.772491, train error 65.47,  test loss 1.634178, test error 64.65
# Epoch   700, train loss 1.766620, train error 64.97,  test loss 1.646779, test error 64.32
# Epoch   800, train loss 1.765045, train error 66.10,  test loss 1.641693, test error 64.62
# Epoch   900, train loss 1.761474, train error 64.75,  test loss 1.642514, test error 64.68
# Training model with   6 hidden variables
# Epoch     0, train loss 2.205597, train error 83.72,  test loss 2.186665, test error 81.78
# Epoch   100, train loss 1.741801, train error 63.58,  test loss 1.603771, test error 63.00
# Epoch   200, train loss 1.668400, train error 60.40,  test loss 1.519158, test error 59.75
# Epoch   300, train loss 1.651734, train error 59.92,  test loss 1.513128, test error 58.97
# Epoch   400, train loss 1.638284, train error 59.05,  test loss 1.497910, test error 57.55
# Epoch   500, train loss 1.633011, train error 59.17,  test loss 1.494512, test error 57.53
# Epoch   600, train loss 1.632089, train error 58.55,  test loss 1.512648, test error 57.92
# Epoch   700, train loss 1.627665, train error 58.85,  test loss 1.505482, test error 57.40
# Epoch   800, train loss 1.626922, train error 58.97,  test loss 1.500734, test error 57.95
# Epoch   900, train loss 1.625604, train error 58.67,  test loss 1.504576, test error 57.78
# Training model with   8 hidden variables
# Epoch     0, train loss 2.294212, train error 87.78,  test loss 2.284517, test error 86.78
# Epoch   100, train loss 1.650053, train error 58.28,  test loss 1.465162, test error 55.97
# Epoch   200, train loss 1.621208, train error 57.12,  test loss 1.453021, test error 55.62
# Epoch   300, train loss 1.603837, train error 55.90,  test loss 1.457038, test error 56.33
# Epoch   400, train loss 1.584636, train error 54.90,  test loss 1.468385, test error 56.12
# Epoch   500, train loss 1.576012, train error 55.00,  test loss 1.465758, test error 56.58
# Epoch   600, train loss 1.562271, train error 54.50,  test loss 1.463802, test error 55.38
# Epoch   700, train loss 1.550961, train error 54.30,  test loss 1.458128, test error 56.10
# Epoch   800, train loss 1.546129, train error 54.30,  test loss 1.461448, test error 55.65
# Epoch   900, train loss 1.544518, train error 54.92,  test loss 1.477240, test error 56.33
# Training model with  10 hidden variables
# Epoch     0, train loss 2.263844, train error 86.07,  test loss 2.256632, test error 85.78
# Epoch   100, train loss 1.645819, train error 58.58,  test loss 1.544598, test error 60.08
# Epoch   200, train loss 1.494216, train error 51.47,  test loss 1.397366, test error 52.28
# Epoch   300, train loss 1.449802, train error 49.92,  test loss 1.377524, test error 50.25
# Epoch   400, train loss 1.438822, train error 49.20,  test loss 1.379447, test error 50.90
# Epoch   500, train loss 1.423221, train error 48.88,  test loss 1.363364, test error 50.17
# Epoch   600, train loss 1.408011, train error 48.75,  test loss 1.331981, test error 49.25
# Epoch   700, train loss 1.392579, train error 47.90,  test loss 1.339074, test error 49.97
# Epoch   800, train loss 1.394887, train error 47.65,  test loss 1.354241, test error 49.65
# Epoch   900, train loss 1.391117, train error 47.80,  test loss 1.357138, test error 50.17
# Training model with  14 hidden variables
# Epoch     0, train loss 2.199402, train error 81.82,  test loss 2.144871, test error 79.93
# Epoch   100, train loss 1.503991, train error 51.15,  test loss 1.452303, test error 54.92
# Epoch   200, train loss 1.426486, train error 48.38,  test loss 1.412121, test error 53.08
# Epoch   300, train loss 1.381484, train error 47.10,  test loss 1.381613, test error 51.83
# Epoch   400, train loss 1.368605, train error 46.53,  test loss 1.407234, test error 52.88
# Epoch   500, train loss 1.351662, train error 45.85,  test loss 1.414989, test error 51.83
# Epoch   600, train loss 1.346467, train error 46.10,  test loss 1.433630, test error 52.35
# Epoch   700, train loss 1.330547, train error 45.28,  test loss 1.427442, test error 52.22
# Epoch   800, train loss 1.322843, train error 45.08,  test loss 1.464535, test error 52.72
# Epoch   900, train loss 1.313556, train error 44.53,  test loss 1.472728, test error 52.83
# Training model with  18 hidden variables
# Epoch     0, train loss 2.189411, train error 81.65,  test loss 2.167828, test error 80.35
# Epoch   100, train loss 1.349124, train error 45.08,  test loss 1.323923, test error 49.85
# Epoch   200, train loss 1.246081, train error 41.12,  test loss 1.311193, test error 47.58
# Epoch   300, train loss 1.214764, train error 39.30,  test loss 1.355943, test error 48.97
# Epoch   400, train loss 1.198724, train error 39.85,  test loss 1.398500, test error 49.22
# Epoch   500, train loss 1.167768, train error 38.45,  test loss 1.426934, test error 49.38
# Epoch   600, train loss 1.160560, train error 38.17,  test loss 1.452486, test error 48.75
# Epoch   700, train loss 1.152213, train error 38.38,  test loss 1.477239, test error 50.35
# Epoch   800, train loss 1.137373, train error 37.80,  test loss 1.476937, test error 49.92
# Epoch   900, train loss 1.149764, train error 38.67,  test loss 1.501023, test error 50.17
# Training model with  22 hidden variables
# Epoch     0, train loss 2.103972, train error 80.12,  test loss 2.052310, test error 79.65
# Epoch   100, train loss 1.221576, train error 40.80,  test loss 1.322012, test error 47.83
# Epoch   200, train loss 1.116913, train error 37.90,  test loss 1.402757, test error 49.10
# Epoch   300, train loss 1.064987, train error 36.90,  test loss 1.483309, test error 49.33
# Epoch   400, train loss 1.029356, train error 35.57,  test loss 1.562998, test error 50.60
# Epoch   500, train loss 1.027400, train error 35.75,  test loss 1.622373, test error 50.60
# Epoch   600, train loss 1.002945, train error 34.75,  test loss 1.636905, test error 50.20
# Epoch   700, train loss 1.009224, train error 34.82,  test loss 1.712658, test error 53.12
# Epoch   800, train loss 0.980199, train error 33.65,  test loss 1.716598, test error 51.88
# Epoch   900, train loss 0.968964, train error 33.12,  test loss 1.755055, test error 51.72
# Training model with  26 hidden variables
# Epoch     0, train loss 2.110885, train error 79.10,  test loss 2.082549, test error 78.78
# Epoch   100, train loss 1.199710, train error 39.22,  test loss 1.323274, test error 48.83
# Epoch   200, train loss 1.050290, train error 34.75,  test loss 1.441870, test error 50.30
# Epoch   300, train loss 0.965683, train error 32.45,  test loss 1.582993, test error 51.53
# Epoch   400, train loss 0.909801, train error 30.38,  test loss 1.710024, test error 51.83
# Epoch   500, train loss 0.884180, train error 29.25,  test loss 1.807339, test error 51.88
# Epoch   600, train loss 0.858656, train error 28.00,  test loss 1.877811, test error 52.05
# Epoch   700, train loss 0.846842, train error 28.05,  test loss 1.913489, test error 51.78
# Epoch   800, train loss 0.821569, train error 27.28,  test loss 2.007205, test error 52.45
# Epoch   900, train loss 0.827025, train error 28.35,  test loss 2.112316, test error 54.12
# Training model with  30 hidden variables
# Epoch     0, train loss 2.189630, train error 80.20,  test loss 2.162180, test error 80.28
# Epoch   100, train loss 1.112257, train error 36.25,  test loss 1.294316, test error 46.62
# Epoch   200, train loss 0.931665, train error 31.07,  test loss 1.476374, test error 49.50
# Epoch   300, train loss 0.821786, train error 26.38,  test loss 1.638287, test error 50.58
# Epoch   400, train loss 0.777104, train error 25.05,  test loss 1.829892, test error 50.97
# Epoch   500, train loss 0.732955, train error 23.53,  test loss 2.006635, test error 52.50
# Epoch   600, train loss 0.720020, train error 23.72,  test loss 2.173788, test error 52.90
# Epoch   700, train loss 0.683187, train error 21.88,  test loss 2.302180, test error 52.12
# Epoch   800, train loss 0.677142, train error 21.22,  test loss 2.419301, test error 52.22
# Epoch   900, train loss 0.639325, train error 19.95,  test loss 2.540203, test error 53.12
# Training model with  35 hidden variables
# Epoch     0, train loss 2.101783, train error 77.45,  test loss 2.032668, test error 76.93
# Epoch   100, train loss 1.020191, train error 33.85,  test loss 1.334135, test error 48.35
# Epoch   200, train loss 0.810855, train error 27.60,  test loss 1.673832, test error 51.17
# Epoch   300, train loss 0.680755, train error 22.82,  test loss 1.971408, test error 52.25
# Epoch   400, train loss 0.636256, train error 22.18,  test loss 2.345040, test error 54.60
# Epoch   500, train loss 0.572617, train error 19.47,  test loss 2.575051, test error 53.00
# Epoch   600, train loss 0.561027, train error 20.03,  test loss 2.850531, test error 54.42
# Epoch   700, train loss 0.490908, train error 17.57,  test loss 3.098798, test error 55.75
# Epoch   800, train loss 0.533415, train error 20.07,  test loss 3.519960, test error 56.00
# Epoch   900, train loss 0.476152, train error 18.10,  test loss 3.714765, test error 56.70
# Training model with  40 hidden variables
# Epoch     0, train loss 2.153362, train error 79.70,  test loss 2.116760, test error 80.45
# Epoch   100, train loss 0.896662, train error 28.35,  test loss 1.439502, test error 49.10
# Epoch   200, train loss 0.650051, train error 20.57,  test loss 1.924628, test error 53.17
# Epoch   300, train loss 0.490811, train error 14.97,  test loss 2.551119, test error 54.83
# Epoch   400, train loss 0.482615, train error 15.72,  test loss 3.410287, test error 55.97
# Epoch   500, train loss 0.381717, train error 12.75,  test loss 4.000861, test error 56.70
# Epoch   600, train loss 0.293664, train error 9.55,  test loss 4.658225, test error 56.00
# Epoch   700, train loss 0.266981, train error 9.03,  test loss 5.148030, test error 56.33
# Epoch   800, train loss 0.271265, train error 8.97,  test loss 5.774304, test error 56.42
# Epoch   900, train loss 0.294275, train error 10.40,  test loss 6.345160, test error 57.28
# Training model with  45 hidden variables
# Epoch     0, train loss 2.096297, train error 77.03,  test loss 2.047398, test error 78.03
# Epoch   100, train loss 0.785586, train error 25.88,  test loss 1.447203, test error 48.90
# Epoch   200, train loss 0.474159, train error 15.25,  test loss 2.260377, test error 51.75
# Epoch   300, train loss 0.278826, train error 7.85,  test loss 3.284019, test error 54.60
# Epoch   400, train loss 0.167677, train error 4.62,  test loss 4.611639, test error 55.12
# Epoch   500, train loss 0.178518, train error 6.47,  test loss 6.090203, test error 56.62
# Epoch   600, train loss 0.143441, train error 4.82,  test loss 7.118334, test error 56.05
# Epoch   700, train loss 0.009183, train error 0.00,  test loss 8.167075, test error 55.72
# Epoch   800, train loss 0.005939, train error 0.00,  test loss 8.711713, test error 56.00
# Epoch   900, train loss 0.004544, train error 0.00,  test loss 9.126544, test error 56.17
# Training model with  50 hidden variables
# Epoch     0, train loss 2.084994, train error 76.95,  test loss 2.030161, test error 77.05
# Epoch   100, train loss 0.726388, train error 23.00,  test loss 1.480786, test error 48.60
# Epoch   200, train loss 0.346423, train error 10.30,  test loss 2.494396, test error 52.72
# Epoch   300, train loss 0.143225, train error 3.38,  test loss 4.017679, test error 54.62
# Epoch   400, train loss 0.035583, train error 0.00,  test loss 5.596817, test error 54.70
# Epoch   500, train loss 0.015837, train error 0.00,  test loss 6.630269, test error 55.00
# Epoch   600, train loss 0.009691, train error 0.00,  test loss 7.281309, test error 55.08
# Epoch   700, train loss 0.006892, train error 0.00,  test loss 7.785492, test error 55.38
# Epoch   800, train loss 0.005255, train error 0.00,  test loss 8.170338, test error 55.35
# Epoch   900, train loss 0.004194, train error 0.00,  test loss 8.498509, test error 55.40
# Training model with  55 hidden variables
# Epoch     0, train loss 2.097936, train error 78.50,  test loss 2.061416, test error 79.22
# Epoch   100, train loss 0.613269, train error 19.43,  test loss 1.704286, test error 51.65
# Epoch   200, train loss 0.197710, train error 4.25,  test loss 3.025413, test error 54.20
# Epoch   300, train loss 0.036479, train error 0.03,  test loss 4.704377, test error 54.47
# Epoch   400, train loss 0.013986, train error 0.00,  test loss 5.690094, test error 54.92
# Epoch   500, train loss 0.008098, train error 0.00,  test loss 6.285725, test error 55.05
# Epoch   600, train loss 0.005615, train error 0.00,  test loss 6.715055, test error 55.08
# Epoch   700, train loss 0.004223, train error 0.00,  test loss 7.054097, test error 54.85
# Epoch   800, train loss 0.003349, train error 0.00,  test loss 7.328889, test error 54.90
# Epoch   900, train loss 0.002756, train error 0.00,  test loss 7.564814, test error 55.05
# Training model with  60 hidden variables
# Epoch     0, train loss 2.032884, train error 76.30,  test loss 1.971510, test error 76.12
# Epoch   100, train loss 0.493522, train error 15.12,  test loss 1.808601, test error 51.08
# Epoch   200, train loss 0.097771, train error 0.80,  test loss 3.492200, test error 52.58
# Epoch   300, train loss 0.018692, train error 0.00,  test loss 4.847664, test error 53.42
# Epoch   400, train loss 0.009176, train error 0.00,  test loss 5.548266, test error 53.40
# Epoch   500, train loss 0.005812, train error 0.00,  test loss 6.008590, test error 53.45
# Epoch   600, train loss 0.004202, train error 0.00,  test loss 6.355817, test error 53.75
# Epoch   700, train loss 0.003227, train error 0.00,  test loss 6.627292, test error 53.72
# Epoch   800, train loss 0.002597, train error 0.00,  test loss 6.848771, test error 53.78
# Epoch   900, train loss 0.002162, train error 0.00,  test loss 7.042936, test error 53.55
# Training model with  70 hidden variables
# Epoch     0, train loss 2.048306, train error 76.57,  test loss 2.002305, test error 77.72
# Epoch   100, train loss 0.371509, train error 10.55,  test loss 1.905101, test error 50.90
# Epoch   200, train loss 0.032319, train error 0.00,  test loss 3.549501, test error 53.22
# Epoch   300, train loss 0.011010, train error 0.00,  test loss 4.322737, test error 53.25
# Epoch   400, train loss 0.006169, train error 0.00,  test loss 4.758235, test error 53.22
# Epoch   500, train loss 0.004132, train error 0.00,  test loss 5.062155, test error 53.35
# Epoch   600, train loss 0.003062, train error 0.00,  test loss 5.291179, test error 53.38
# Epoch   700, train loss 0.002407, train error 0.00,  test loss 5.480450, test error 53.53
# Epoch   800, train loss 0.001964, train error 0.00,  test loss 5.638141, test error 53.60
# Epoch   900, train loss 0.001651, train error 0.00,  test loss 5.772848, test error 53.50
# Training model with  80 hidden variables
# Epoch     0, train loss 2.017729, train error 74.70,  test loss 1.963509, test error 75.07
# Epoch   100, train loss 0.240199, train error 4.07,  test loss 2.008426, test error 50.30
# Epoch   200, train loss 0.020594, train error 0.00,  test loss 3.342030, test error 51.12
# Epoch   300, train loss 0.008218, train error 0.00,  test loss 3.889998, test error 51.25
# Epoch   400, train loss 0.004861, train error 0.00,  test loss 4.208165, test error 51.15
# Epoch   500, train loss 0.003344, train error 0.00,  test loss 4.440820, test error 51.00
# Epoch   600, train loss 0.002508, train error 0.00,  test loss 4.616431, test error 51.05
# Epoch   700, train loss 0.001989, train error 0.00,  test loss 4.763937, test error 51.15
# Epoch   800, train loss 0.001637, train error 0.00,  test loss 4.886105, test error 51.12
# Epoch   900, train loss 0.001383, train error 0.00,  test loss 4.991580, test error 51.08
# Training model with  90 hidden variables
# Epoch     0, train loss 2.001837, train error 74.50,  test loss 1.948044, test error 74.88
# Epoch   100, train loss 0.130719, train error 0.88,  test loss 2.292728, test error 53.05
# Epoch   200, train loss 0.014850, train error 0.00,  test loss 3.402318, test error 54.42
# Epoch   300, train loss 0.006647, train error 0.00,  test loss 3.851143, test error 54.30
# Epoch   400, train loss 0.004052, train error 0.00,  test loss 4.132641, test error 54.10
# Epoch   500, train loss 0.002850, train error 0.00,  test loss 4.334886, test error 54.30
# Epoch   600, train loss 0.002165, train error 0.00,  test loss 4.491177, test error 54.35
# Epoch   700, train loss 0.001731, train error 0.00,  test loss 4.620042, test error 54.40
# Epoch   800, train loss 0.001432, train error 0.00,  test loss 4.729540, test error 54.47
# Epoch   900, train loss 0.001215, train error 0.00,  test loss 4.823990, test error 54.50
# Training model with 100 hidden variables
# Epoch     0, train loss 1.987148, train error 73.47,  test loss 1.908542, test error 73.35
# Epoch   100, train loss 0.095454, train error 0.12,  test loss 2.308682, test error 52.12
# Epoch   200, train loss 0.012532, train error 0.00,  test loss 3.241557, test error 52.80
# Epoch   300, train loss 0.005804, train error 0.00,  test loss 3.628202, test error 52.90
# Epoch   400, train loss 0.003617, train error 0.00,  test loss 3.873604, test error 52.88
# Epoch   500, train loss 0.002571, train error 0.00,  test loss 4.050229, test error 53.05
# Epoch   600, train loss 0.001969, train error 0.00,  test loss 4.188579, test error 52.95
# Epoch   700, train loss 0.001581, train error 0.00,  test loss 4.303282, test error 53.03
# Epoch   800, train loss 0.001314, train error 0.00,  test loss 4.399372, test error 53.08
# Epoch   900, train loss 0.001118, train error 0.00,  test loss 4.484173, test error 53.15
# Training model with 120 hidden variables
# Epoch     0, train loss 1.974329, train error 72.15,  test loss 1.922483, test error 74.03
# Epoch   100, train loss 0.053780, train error 0.03,  test loss 2.151689, test error 49.78
# Epoch   200, train loss 0.009684, train error 0.00,  test loss 2.780129, test error 50.35
# Epoch   300, train loss 0.004773, train error 0.00,  test loss 3.057127, test error 50.50
# Epoch   400, train loss 0.003046, train error 0.00,  test loss 3.235576, test error 50.58
# Epoch   500, train loss 0.002195, train error 0.00,  test loss 3.367082, test error 50.72
# Epoch   600, train loss 0.001696, train error 0.00,  test loss 3.470644, test error 50.67
# Epoch   700, train loss 0.001371, train error 0.00,  test loss 3.555758, test error 50.72
# Epoch   800, train loss 0.001145, train error 0.00,  test loss 3.629599, test error 50.83
# Epoch   900, train loss 0.000978, train error 0.00,  test loss 3.692126, test error 50.88
# Training model with 140 hidden variables
# Epoch     0, train loss 1.967838, train error 72.60,  test loss 1.907120, test error 73.97
# Epoch   100, train loss 0.035616, train error 0.00,  test loss 2.160155, test error 49.17
# Epoch   200, train loss 0.007992, train error 0.00,  test loss 2.626648, test error 48.88
# Epoch   300, train loss 0.004109, train error 0.00,  test loss 2.853237, test error 48.83
# Epoch   400, train loss 0.002666, train error 0.00,  test loss 2.999361, test error 48.95
# Epoch   500, train loss 0.001939, train error 0.00,  test loss 3.107713, test error 48.72
# Epoch   600, train loss 0.001507, train error 0.00,  test loss 3.194975, test error 48.80
# Epoch   700, train loss 0.001223, train error 0.00,  test loss 3.267232, test error 48.80
# Epoch   800, train loss 0.001025, train error 0.00,  test loss 3.328496, test error 48.83
# Epoch   900, train loss 0.000878, train error 0.00,  test loss 3.382379, test error 48.72
# Training model with 160 hidden variables
# Epoch     0, train loss 1.949539, train error 72.05,  test loss 1.889241, test error 73.78
# Epoch   100, train loss 0.027863, train error 0.00,  test loss 2.071165, test error 48.70
# Epoch   200, train loss 0.007078, train error 0.00,  test loss 2.474403, test error 48.60
# Epoch   300, train loss 0.003739, train error 0.00,  test loss 2.672101, test error 48.45
# Epoch   400, train loss 0.002453, train error 0.00,  test loss 2.802627, test error 48.38
# Epoch   500, train loss 0.001797, train error 0.00,  test loss 2.899291, test error 48.53
# Epoch   600, train loss 0.001403, train error 0.00,  test loss 2.977436, test error 48.45
# Epoch   700, train loss 0.001143, train error 0.00,  test loss 3.042369, test error 48.47
# Epoch   800, train loss 0.000959, train error 0.00,  test loss 3.098364, test error 48.45
# Epoch   900, train loss 0.000823, train error 0.00,  test loss 3.146916, test error 48.60
# Training model with 180 hidden variables
# Epoch     0, train loss 1.923286, train error 70.70,  test loss 1.850202, test error 71.12
# Epoch   100, train loss 0.025105, train error 0.00,  test loss 2.078955, test error 48.53
# Epoch   200, train loss 0.006651, train error 0.00,  test loss 2.444296, test error 49.12
# Epoch   300, train loss 0.003555, train error 0.00,  test loss 2.629745, test error 49.15
# Epoch   400, train loss 0.002352, train error 0.00,  test loss 2.751339, test error 49.10
# Epoch   500, train loss 0.001728, train error 0.00,  test loss 2.843885, test error 49.17
# Epoch   600, train loss 0.001353, train error 0.00,  test loss 2.919077, test error 49.17
# Epoch   700, train loss 0.001104, train error 0.00,  test loss 2.980651, test error 49.17
# Epoch   800, train loss 0.000928, train error 0.00,  test loss 3.033281, test error 49.08
# Epoch   900, train loss 0.000797, train error 0.00,  test loss 3.079832, test error 49.08
# Training model with 200 hidden variables
# Epoch     0, train loss 1.955001, train error 71.97,  test loss 1.848107, test error 71.90
# Epoch   100, train loss 0.021227, train error 0.00,  test loss 2.033069, test error 48.47
# Epoch   200, train loss 0.006061, train error 0.00,  test loss 2.356955, test error 48.60
# Epoch   300, train loss 0.003285, train error 0.00,  test loss 2.524286, test error 48.65
# Epoch   400, train loss 0.002188, train error 0.00,  test loss 2.634404, test error 48.58
# Epoch   500, train loss 0.001616, train error 0.00,  test loss 2.718307, test error 48.58
# Epoch   600, train loss 0.001268, train error 0.00,  test loss 2.785866, test error 48.60
# Epoch   700, train loss 0.001037, train error 0.00,  test loss 2.841787, test error 48.62
# Epoch   800, train loss 0.000873, train error 0.00,  test loss 2.889759, test error 48.62
# Epoch   900, train loss 0.000752, train error 0.00,  test loss 2.931970, test error 48.65
# Training model with 250 hidden variables
# Epoch     0, train loss 1.909140, train error 69.03,  test loss 1.817422, test error 69.50
# Epoch   100, train loss 0.017299, train error 0.00,  test loss 1.896179, test error 46.75
# Epoch   200, train loss 0.005400, train error 0.00,  test loss 2.156760, test error 46.72
# Epoch   300, train loss 0.002999, train error 0.00,  test loss 2.292835, test error 46.65
# Epoch   400, train loss 0.002023, train error 0.00,  test loss 2.386928, test error 46.70
# Epoch   500, train loss 0.001505, train error 0.00,  test loss 2.457984, test error 46.53
# Epoch   600, train loss 0.001188, train error 0.00,  test loss 2.516204, test error 46.60
# Epoch   700, train loss 0.000975, train error 0.00,  test loss 2.563700, test error 46.62
# Epoch   800, train loss 0.000823, train error 0.00,  test loss 2.604920, test error 46.67
# Epoch   900, train loss 0.000710, train error 0.00,  test loss 2.640991, test error 46.67
# Training model with 300 hidden variables
# Epoch     0, train loss 1.956305, train error 72.47,  test loss 1.887387, test error 74.53
# Epoch   100, train loss 0.014296, train error 0.00,  test loss 1.898651, test error 47.15
# Epoch   200, train loss 0.004780, train error 0.00,  test loss 2.120618, test error 46.72
# Epoch   300, train loss 0.002711, train error 0.00,  test loss 2.241598, test error 46.62
# Epoch   400, train loss 0.001847, train error 0.00,  test loss 2.325447, test error 46.72
# Epoch   500, train loss 0.001382, train error 0.00,  test loss 2.389531, test error 46.85
# Epoch   600, train loss 0.001096, train error 0.00,  test loss 2.440909, test error 46.83
# Epoch   700, train loss 0.000902, train error 0.00,  test loss 2.484707, test error 46.83
# Epoch   800, train loss 0.000764, train error 0.00,  test loss 2.522072, test error 46.85
# Epoch   900, train loss 0.000660, train error 0.00,  test loss 2.555064, test error 46.83
# Training model with 400 hidden variables
# Epoch     0, train loss 1.852070, train error 67.70,  test loss 1.807223, test error 69.88
# Epoch   100, train loss 0.011376, train error 0.00,  test loss 1.770061, test error 44.70
# Epoch   200, train loss 0.004098, train error 0.00,  test loss 1.940437, test error 44.75
# Epoch   300, train loss 0.002381, train error 0.00,  test loss 2.035625, test error 44.62
# Epoch   400, train loss 0.001643, train error 0.00,  test loss 2.102357, test error 44.78
# Epoch   500, train loss 0.001239, train error 0.00,  test loss 2.153808, test error 44.78
# Epoch   600, train loss 0.000987, train error 0.00,  test loss 2.195169, test error 44.90
# Epoch   700, train loss 0.000816, train error 0.00,  test loss 2.230345, test error 44.83
# Epoch   800, train loss 0.000693, train error 0.00,  test loss 2.260514, test error 44.85
# Epoch   900, train loss 0.000601, train error 0.00,  test loss 2.286895, test error 44.85

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all,'r-',label='train')
ax.plot(hidden_variables, errors_test_all,'b-',label='test')
ax.set_ylim(0,100);
ax.set_xlabel('No hidden variables'); ax.set_ylabel('Error')
ax.legend()
plt.show()
